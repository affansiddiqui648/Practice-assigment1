# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
season=pd.read_csv("/content/deliveries.csv")
season
# Out:
#        match_id  season  start_date                                  venue  \
# 0             1    2024  2024-06-02             Providence Stadium, Guyana
# 1             1    2024  2024-06-02             Providence Stadium, Guyana
# 2             1    2024  2024-06-02             Providence Stadium, Guyana
# 3             1    2024  2024-06-02             Providence Stadium, Guyana
# 4             1    2024  2024-06-02             Providence Stadium, Guyana
# ...         ...     ...         ...                                    ...
# 11467        54    2024  2024-06-29  Kensington Oval, Bridgetown, Barbados
# 11468        54    2024  2024-06-29  Kensington Oval, Bridgetown, Barbados
# 11469        54    2024  2024-06-29  Kensington Oval, Bridgetown, Barbados
# 11470        54    2024  2024-06-29  Kensington Oval, Bridgetown, Barbados
# 11471        54    2024  2024-06-29  Kensington Oval, Bridgetown, Barbados
#
# ...

# %%
season.plot(y='season',x='start_date')
season.plot(y=['season','venue'], x='start_date')
# Out:
# <Axes: xlabel='start_date'>

# %%
season.plot.bar(y='season', x='start_date')
# Out:
# <Axes: xlabel='start_date'>

# %%
season.plot.scatter(y='match_id', x='start_date')
# Out:
# <Axes: xlabel='start_date', ylabel='match_id'>

# %%
# Data set of heros
mostviewer=pd.read_csv('/content/critic_reviews.csv')
mostviewer
# Out:
#         reviewId creationDate          criticName  \
# 0        1912176   1966-07-30      Jennie Kermode
# 1        1895073   1998-08-21          Scott Nash
# 2          25507   2000-01-01         Roger Ebert
# 3          25508   2000-01-01                 NaN
# 4          25509   2000-01-01           Joe Brown
# ...          ...          ...                 ...
# 27137  102921224   2024-06-14          Mat Brunet
# 27138  102921566   2024-06-15         Josh Larsen
# 27139  102921714   2024-06-17         Casey Chong
# 27140  102923356   2024-06-24  Udita Jhunjhunwala
# 27141  102923418   2024-06-24  Udita Jhunjhunwala
#
#                      criticPageUrl reviewState  isFresh  isRotten isRtUrl  \
# 0          /critics/jennie-kermode       fresh     True     False   False
# 1              /critics/scott-nash       fresh     True     False   False
# 2             /critics/roger-ebert       fresh     True     False   False
# ...

# %%
# This is the head cuted data
mostviewer.head(2)
# Out:
#    reviewId creationDate      criticName            criticPageUrl reviewState  \
# 0   1912176   1966-07-30  Jennie Kermode  /critics/jennie-kermode       fresh
# 1   1895073   1998-08-21      Scott Nash      /critics/scott-nash       fresh
#
#    isFresh  isRotten isRtUrl  isTopCritic        publicationUrl  \
# 0     True     False   False        False  /critics/source/1869
# 1     True     False   False        False  /critics/source/1465
#
#      publicationName                                        reviewUrl  \
# 0       Eye for Film  http://www.eyeforfilm.co.uk/reviews.php?id=7898
# 1  Three Movie Buffs      http://www.threemoviebuffs.com/review/blade
#
#                                                quote scoreSentiment  \
# 0                                                NaN       POSITIVE
# 1  It's stylish and fast-paced. It's also a lot o...       POSITIVE
#
#   originalScore                               movieId
# 0           4/5  7602d2ab-c9bc-3439-9cd6-d3a06e81728e
# ...

# %%
# This is the Tail cuted data
mostviewer.tail(5)
# Out:
#         reviewId creationDate          criticName  \
# 27137  102921224   2024-06-14          Mat Brunet
# 27138  102921566   2024-06-15         Josh Larsen
# 27139  102921714   2024-06-17         Casey Chong
# 27140  102923356   2024-06-24  Udita Jhunjhunwala
# 27141  102923418   2024-06-24  Udita Jhunjhunwala
#
#                      criticPageUrl reviewState  isFresh  isRotten isRtUrl  \
# 27137          /critics/mat-brunet       fresh     True     False   False
# 27138         /critics/josh-larsen       fresh     True     False   False
# 27139         /critics/casey-chong       fresh     True     False   False
# 27140  /critics/udita-jhunjhunwala       fresh     True     False   False
# 27141  /critics/udita-jhunjhunwala      rotten    False      True   False
#
#        isTopCritic             publicationUrl            publicationName  \
# 27137        False  /critics/source/100009579  AniMat's Review (YouTube)
# ...

# %% [markdown]
# COLUMNS

# %%
mostviewer.columns
# Out:
# Index(['reviewId', 'creationDate', 'criticName', 'criticPageUrl',
#        'reviewState', 'isFresh', 'isRotten', 'isRtUrl', 'isTopCritic',
#        'publicationUrl', 'publicationName', 'reviewUrl', 'quote',
#        'scoreSentiment', 'originalScore', 'movieId'],
#       dtype='object')

# %%
mostviewer.describe()
# Out:
#            reviewId
# count  2.714200e+04
# mean   1.628587e+07
# std    3.493963e+07
# min    1.705000e+03
# 25%    2.082886e+06
# 50%    2.407968e+06
# 75%    2.667693e+06
# max    1.029234e+08
